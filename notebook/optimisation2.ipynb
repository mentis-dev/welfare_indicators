# %%
import pandas as pd
import numpy as np
from ortools.linear_solver import pywraplp

nb_indicators=5

df=pd.read_csv("../data/dairy_cows.csv")
df.head()
# Out:
#    ID     Species Animal_Class               Welfare_Hazards_Animal  \
# 0   1  Dairy cows   Tie stalls                       Pasture access
# 1   1  Dairy cows     Cubicles                       Pasture access
# 2   2  Dairy cows   Tie stalls  Continuous housing for long periods
# 3   2  Dairy cows     Cubicles  Continuous housing for long periods
# 4   3  Dairy cows   Tie stalls                   Insufficient space
#
#       Welfare_Hazards_Consequences Welfare_Hazards_Impact  \
# 0         Gastro-enteric disorders                   High
# 1         Gastro-enteric disorders                   High
# 2  General disruption of behaviour                    Low
# 3  General disruption of behaviour                    Low
# 4          Restriction of movement                   High
#
#   Ease_of_Hazard_Mitigation       Welfare_Indicator Indicator_Ease  \
# 0                  Moderate    Abdominal discomfort       Moderate
# 1                  Moderate    Abdominal discomfort       Moderate
# 2                 Difficult     Agonistic behaviour       Moderate
# 3                 Difficult     Agonistic behaviour       Moderate
# 4                  Moderate  Agonistic interactions       Moderate
#
#   Indicator_Resources
# 0                 Low
# 1                 Low
# 2                 Low
# 3                 Low
# 4              Medium

# %%
ease_mapping = {'Easy': 1, 'Moderate': 2, 'Difficult': 3}
resources_mapping = {'Low': 1, 'Medium': 2, 'High': 3}
impact_mapping = {'Low': 1, 'High': 2}

# Apply mappings
df['Indicator_Ease_Num'] = df['Indicator_Ease'].map(ease_mapping)
df['Ease_of_Hazard_Mitigation_Num'] = df['Ease_of_Hazard_Mitigation'].map(ease_mapping)
df['Indicator_Resources_Num'] = df['Indicator_Resources'].map(resources_mapping)
df['Welfare_Hazards_Impact_Num'] = df['Welfare_Hazards_Impact'].map(impact_mapping)

# %%
# List of unique Welfare Indicators
indicators_list = df['Welfare_Indicator'].unique().tolist()

# List of unique Welfare_Hazards_Animal
hazards_animal_list = df['Welfare_Hazards_Animal'].unique().tolist()

# List of unique Welfare_Hazards_Consequences
hazards_consequence_list = df['Welfare_Hazards_Consequences'].unique().tolist()

# %%
# Initialize a_hi_animal dictionary
a_hi_animal = {h: {i: 0 for i in indicators_list} for h in hazards_animal_list}

# Populate the dictionary
for idx, row in df.iterrows():
    h = row['Welfare_Hazards_Animal']
    i = row['Welfare_Indicator']
    a_hi_animal[h][i] = 1

# %%
# Initialize a_ci_consequence dictionary
a_ci_consequence = {c: {i: 0 for i in indicators_list} for c in hazards_consequence_list}

# Populate the dictionary
for idx, row in df.iterrows():
    c = row['Welfare_Hazards_Consequences']
    i = row['Welfare_Indicator']
    a_ci_consequence[c][i] = 1  # Indicator i addresses consequence c

# %%
indicator_attributes = df.groupby('Welfare_Indicator').agg({
    'Indicator_Ease_Num': 'mean',
    'Ease_of_Hazard_Mitigation_Num': 'mean',
    'Indicator_Resources_Num': 'mean'
}).to_dict('index')

# %%
# Hazard impact for animal hazards
hazard_animal_impact = df.groupby('Welfare_Hazards_Animal')['Welfare_Hazards_Impact_Num'].mean().to_dict()

# Hazard impact for consequences
hazard_consequence_impact = df.groupby('Welfare_Hazards_Consequences')['Welfare_Hazards_Impact_Num'].mean().to_dict()

# %%
solver = pywraplp.Solver.CreateSolver('CBC')
solver.EnableOutput()

# %% [markdown]
# ## prepear decision variables

# %%
# Decision variables for indicator selection
x_vars = {}
for i in indicators_list:
    x_vars[i] = solver.IntVar(0, 1, f'Select_Indicator_{i}')

# Decision variables for animal hazard coverage
y_vars_animal = {}
for h in hazards_animal_list:
    y_vars_animal[h] = solver.IntVar(0, 1, f'Cover_Hazard_Animal_{h}')

# Decision variables for consequence coverage
y_vars_consequence = {}
for c in hazards_consequence_list:
    y_vars_consequence[c] = solver.IntVar(0, 1, f'Cover_Hazard_Consequence_{c}')

# %%
solver.Add(solver.Sum([x_vars[i] for i in indicators_list]) == nb_indicators)
# Out:
# <ortools.linear_solver.pywraplp.Constraint; proxy of <Swig Object of type 'operations_research::MPConstraint *' at 0x11850ae80> >

# %%
#Hazard Coverage Constraints for Animal Hazards
for h in hazards_animal_list:
    # If any indicator covering hazard h is selected, y_vars_animal[h] must be 1
    indicators_covering_h = [x_vars[i] for i in indicators_list if a_hi_animal[h][i] == 1]
    solver.Add(y_vars_animal[h] <= solver.Sum(indicators_covering_h))
    solver.Add(y_vars_animal[h] * len(indicators_covering_h) >= solver.Sum(indicators_covering_h))

#Hazard Coverage Constraints for Consequences

for c in hazards_consequence_list:
    # If any indicator covering consequence c is selected, y_vars_consequence[c] must be 1
    indicators_covering_c = [x_vars[i] for i in indicators_list if a_ci_consequence[c][i] == 1]
    solver.Add(y_vars_consequence[c] <= solver.Sum(indicators_covering_c))
    solver.Add(y_vars_consequence[c] * len(indicators_covering_c) >= solver.Sum(indicators_covering_c))

# %% [markdown]
# ## Objective Function
# ### Set Weights
# To maximize the number of hazards and consequences explained, we'll prioritize maximizing their coverage in the objective function.
#
# Set higher weights for hazard coverage terms.

# %%
weight_animal_hazard_coverage = 1 # High weight to prioritize hazard coverage
weight_consequence_coverage = 1    # High weight to prioritize consequence coverage

beta = 2    # Weight for Indicator_Ease
gamma = 1   # Weight for Ease_of_Hazard_Mitigation
delta = 1   # Weight for Indicator_Resources

# %%
# Objective function components
# Maximize the number of hazards and consequences covered
objective_terms = []

# Animal hazard coverage
for h in hazards_animal_list:
    objective_terms.append(weight_animal_hazard_coverage * y_vars_animal[h])

# Consequence coverage
for c in hazards_consequence_list:
    objective_terms.append(weight_consequence_coverage * y_vars_consequence[c])

# Penalize higher Indicator_Ease, Ease_of_Hazard_Mitigation, and Indicator_Resources
for i in indicators_list:
    indicator_penalty = (
        beta * indicator_attributes[i]['Indicator_Ease_Num'] +
        gamma * indicator_attributes[i]['Ease_of_Hazard_Mitigation_Num'] +
        delta * indicator_attributes[i]['Indicator_Resources_Num']
    )
    objective_terms.append(-indicator_penalty * x_vars[i])

# Set the objective function
solver.Maximize(solver.Sum(objective_terms))

# %%
status = solver.Solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Sep 13 2024
#
# command line - cbc -solve -quit (default strategy 1)
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj -0 Primal inf 2.931988 (1) Dual inf 50866.684 (55)
# 14  Obj 49978.017
# Optimal - objective value 49978.017
# After Postsolve, objective 49978.017, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 49978.01667 - 14 iterations time 0.002, Presolve 0.00
# Continuous objective value is 49978 - 0.00 seconds
# Optimal - objective value 49978.017
# Optimal - objective value 49978.017
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj 49978.017 Dual inf 2870.3322 (6)
# 7  Obj 49978.017
# Optimal - objective value 49978.017
# Presolve 91 (0) rows, 85 (0) columns and 502 (0) elements
# 0  Obj 49978.017
# Optimal - objective value 49978.017
# 0 fixed, 0 tightened bounds, 0 strengthened rows, 16 substitutions
# Optimal - objective value 49978.017
# Presolve 77 (-30) rows, 78 (-7) columns and 452 (-82) elements
# 0  Obj 49978.017 Dual inf 875.0449 (1)
# Perturbing problem by 0.001% of 1.7027888 - largest nonzero change 1.8228516e-05 ( 0.0018228516%) - largest zero change 1.6882569e-05
# 1  Obj 49978.033
# Optimal - objective value 49978.017
# Optimal - objective value 49978.017
# processed model has 77 rows, 78 columns (78 integer (69 of which binary)) and 452 elements
# 0  Obj 49978.017
# Optimal - objective value 49978.017
# Optimal - objective value 49978.017
# Cutoff increment increased from 1e-05 to 0.00237857
# Optimal - objective value -49978.017
# Initial state - 0 integers unsatisfied sum - 7.77156e-16
# Optimal - objective value -49978.017
# Optimal - objective value -49978.017
# 0  Obj 0
# Optimal - objective value 0
# Solution found of -49978
# Cleaned solution of -49978
# 0  Obj -49978.017
# Optimal - objective value -49978.017
# Before mini branch and bound, 78 integers at bound fixed and 0 continuous
# Mini branch and bound did not improve solution (0.00 seconds)
# After 0.00 seconds - Feasibility pump exiting with objective of -49978 - took 0.00 seconds
# Optimal - objective value -49978.017
# Integer solution of -49978.017 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Primal infeasible - objective value -49978.017
# Optimal - objective value -49978.017
# Primal infeasible - objective value -49978.017
# Search completed - best objective -49978.01666666666, took 0 iterations and 0 nodes (0.00 seconds)
# Maximum depth 0, 0 variables fixed on reduced cost
# Optimal - objective value -49978.017
# Optimal - objective value -49978.017
# Cuts at root node changed objective from -49978 to -49978
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Optimal - objective value 49978.017
# Optimal - objective value 49978.017
# Optimal - objective value 49978.017
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Crash put 0 variables in basis, 0 dual infeasibilities
# Optimal - objective value 49978.017
# After Postsolve, objective 49978.017, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal - objective value 49978.017
# Perturbing problem by 0.001% of 1e-08 - largest nonzero change 0 ( 0%) - largest zero change 0
# 0  Obj 49378.017 Primal inf 1.2650894 (1) Dual inf 697.23659 (2)
# 0  Obj 49378.017 Primal inf 1.2650894 (1) Dual inf 1.4704641e+10 (2)
# 1  Obj 49978.017
# Optimal - objective value 49978.017
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Optimal - objective value 49978.017
# After Postsolve, objective 49978.017, infeasibilities - dual 0 (0), primal 0 (0)
#
# Result - Optimal solution found
#
# Objective value:                49978.01666667
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Sep 13 2024
#
# command line - cbc -solve -quit (default strategy 1)
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj -0 Primal inf 2.931988 (1) Dual inf 25.904105 (47)
# 22  Obj 28.516667
# Optimal - objective value 28.516667
# After Postsolve, objective 28.516667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 28.51666667 - 22 iterations time 0.002, Presolve 0.00
# Continuous objective value is 28.5167 - 0.00 seconds
# Optimal - objective value 28.516667
# Optimal - objective value 28.516667
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj 28.516667 Dual inf 6.9541006 (10)
# 10  Obj 28.516667
# Optimal - objective value 28.516667
# Presolve 91 (0) rows, 85 (0) columns and 502 (0) elements
# 0  Obj 28.516667
# Optimal - objective value 28.516667
# 0 fixed, 0 tightened bounds, 0 strengthened rows, 16 substitutions
# Optimal - objective value 28.516667
# Presolve 77 (-30) rows, 78 (-7) columns and 452 (-82) elements
# 0  Obj 28.516667
# Optimal - objective value 28.516667
# Optimal - objective value 28.516667
# processed model has 77 rows, 78 columns (78 integer (69 of which binary)) and 452 elements
# 0  Obj 28.516667
# Optimal - objective value 28.516667
# Optimal - objective value 28.516667
# Cutoff increment increased from 1e-05 to 0.00237857
# Optimal - objective value -28.516667
# Initial state - 0 integers unsatisfied sum - 5.55112e-16
# Optimal - objective value -28.516667
# Optimal - objective value -28.516667
# 0  Obj 0
# Optimal - objective value 0
# Solution found of -28.5167
# Cleaned solution of -28.5167
# 0  Obj -28.516667
# Optimal - objective value -28.516667
# Before mini branch and bound, 78 integers at bound fixed and 0 continuous
# Mini branch and bound did not improve solution (0.00 seconds)
# After 0.00 seconds - Feasibility pump exiting with objective of -28.5167 - took 0.00 seconds
# Optimal - objective value -28.516667
# Integer solution of -28.516667 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Primal infeasible - objective value -28.516667
# Optimal - objective value -28.516667
# Primal infeasible - objective value -28.516667
# Search completed - best objective -28.51666666666667, took 0 iterations and 0 nodes (0.00 seconds)
# Maximum depth 0, 0 variables fixed on reduced cost
# Optimal - objective value -28.516667
# Optimal - objective value -28.516667
# Cuts at root node changed objective from -28.5167 to -28.5167
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Optimal - objective value 28.516667
# 0  Obj 28.516667 Dual inf 1.8499999 (1)
# 1  Obj 28.516667
# Optimal - objective value 28.516667
# Optimal - objective value 28.516667
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Crash put 0 variables in basis, 0 dual infeasibilities
# Optimal - objective value 28.516667
# After Postsolve, objective 28.516667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal - objective value 28.516667
# Perturbing problem by 0.001% of 1e-08 - largest nonzero change 0 ( 0%) - largest zero change 0
# 0  Obj 31.954545 Primal inf 21.213897 (9) Dual inf 1.3210397 (3)
# 0  Obj 31.954545 Primal inf 21.213897 (9) Dual inf 1.6107949e+11 (6)
# 6  Obj 28.516667
# Optimal - objective value 28.516667
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Optimal - objective value 28.516667
# After Postsolve, objective 28.516667, infeasibilities - dual 0 (0), primal 0 (0)
#
# Result - Optimal solution found
#
# Objective value:                28.51666667
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Sep 13 2024
#
# command line - cbc -solve -quit (default strategy 1)
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj -0 Primal inf 2.931988 (1) Dual inf 24.312469 (45)
# 26  Obj 21.516667
# Optimal - objective value 21.516667
# After Postsolve, objective 21.516667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 21.51666667 - 26 iterations time 0.002, Presolve 0.00
# Continuous objective value is 21.5167 - 0.00 seconds
# Optimal - objective value 21.516667
# Optimal - objective value 21.516667
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj 21.516667 Dual inf 1.9786467 (4)
# 4  Obj 21.516667
# Optimal - objective value 21.516667
# Presolve 91 (0) rows, 85 (0) columns and 502 (0) elements
# 0  Obj 21.516667
# Optimal - objective value 21.516667
# 0 fixed, 0 tightened bounds, 0 strengthened rows, 16 substitutions
# Optimal - objective value 21.516667
# Presolve 77 (-30) rows, 78 (-7) columns and 452 (-82) elements
# 0  Obj 21.516667
# Optimal - objective value 21.516667
# Optimal - objective value 21.516667
# processed model has 77 rows, 78 columns (78 integer (69 of which binary)) and 452 elements
# 0  Obj 21.516667
# Optimal - objective value 21.516667
# Optimal - objective value 21.516667
# Cutoff increment increased from 1e-05 to 0.00237857
# Optimal - objective value -21.516667
# Initial state - 0 integers unsatisfied sum - 9.99201e-16
# Optimal - objective value -21.516667
# Optimal - objective value -21.516667
# 0  Obj 0
# Optimal - objective value 0
# Solution found of -21.5167
# Cleaned solution of -21.5167
# 0  Obj -21.516667
# Optimal - objective value -21.516667
# Before mini branch and bound, 78 integers at bound fixed and 0 continuous
# Mini branch and bound did not improve solution (0.00 seconds)
# After 0.00 seconds - Feasibility pump exiting with objective of -21.5167 - took 0.00 seconds
# Optimal - objective value -21.516667
# Integer solution of -21.516667 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Primal infeasible - objective value -21.516667
# Optimal - objective value -21.516667
# Primal infeasible - objective value -21.516667
# Search completed - best objective -21.51666666666667, took 0 iterations and 0 nodes (0.00 seconds)
# Maximum depth 0, 0 variables fixed on reduced cost
# Optimal - objective value -21.516667
# Optimal - objective value -21.516667
# Cuts at root node changed objective from -21.5167 to -21.5167
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Optimal - objective value 21.516667
# Optimal - objective value 21.516667
# Optimal - objective value 21.516667
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Crash put 0 variables in basis, 0 dual infeasibilities
# Optimal - objective value 21.516667
# After Postsolve, objective 21.516667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal - objective value 21.516667
# Perturbing problem by 0.001% of 1e-08 - largest nonzero change 0 ( 0%) - largest zero change 0
# 0  Obj 28.50974 Primal inf 108.83628 (17) Dual inf 2.4358985 (3)
# 0  Obj 28.50974 Primal inf 108.83628 (17) Dual inf 5.2540069e+11 (5)
# 6  Obj 21.516667
# Optimal - objective value 21.516667
# Presolve 0 (-137) rows, 0 (-123) columns and 0 (-690) elements
# Optimal - objective value 21.516667
# After Postsolve, objective 21.516667, infeasibilities - dual 0 (0), primal 0 (0)
#
# Result - Optimal solution found
#
# Objective value:                21.51666667
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Sep 13 2024
#
# command line - cbc -solve -quit (default strategy 1)
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj -0 Primal inf 3.6649852 (1) Dual inf 24.312469 (45)
# 24  Obj 19.016667
# Optimal - objective value 19.016667
# After Postsolve, objective 19.016667, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 19.01666667 - 24 iterations time 0.002, Presolve 0.00
# Continuous objective value is 19.0167 - 0.00 seconds
# Optimal - objective value 19.016667
# Optimal - objective value 19.016667
# Presolve 91 (-46) rows, 85 (-38) columns and 502 (-188) elements
# 0  Obj 19.016667 Dual inf 11.879812 (14)
# 17  Obj 19.016667
# Optimal - objective value 19.016667
# Presolve 91 (0) rows, 85 (0) columns and 502 (0) elements
# 0  Obj 19.016667
# Optimal - objective value 19.016667
# 0 fixed, 0 tightened bounds, 0 strengthened rows, 16 substitutions
# Optimal - objective value 19.016667
# Presolve 77 (-30) rows, 78 (-7) columns and 452 (-82) elements
# 0  Obj 19.016667 Dual inf 0.8750448 (1)
# Perturbing problem by 0.001% of 1.7202046 - largest nonzero change 1.9297435e-05 ( 0.0019297435%) - largest zero change 1.8144682e-05
# 1  Obj 19.016684
# Optimal - objective value 19.016667
# Optimal - objective value 19.016667
# processed model has 77 rows, 78 columns (78 integer (69 of which binary)) and 452 elements
# 0  Obj 19.016667
# Optimal - objective value 19.016667
# Optimal - objective value 19.016667
# Cutoff increment increased from 1e-05 to 0.00237857
# Optimal - objective value -19.016667
# Initial state - 0 integers unsatisfied sum - 4.44089e-16
# Optimal - objective value -19.016667
# Optimal - objective value -19.016667
# 0  Obj 0
# Optimal - objective value 0
# Solution found of -19.0167
# Cleaned solution of -19.0167
# 0  Obj -19.016667
# Optimal - objective value -19.016667
# Before mini branch and bound, 78 integers at bound fixed and 0 continuous
# Mini branch and bound did not improve solution (0.00 seconds)
# After 0.00 seconds - Feasibility pump exiting with objective of -19.0167 - took 0.00 seconds
# Optimal - objective value -19.016667
# Integer solution of -19.016667 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Primal infeasible - objective value -19.016667
# Optimal - objective value -19.016667
# Primal infeasible - objective value -19.016667
# Search completed - best objective -19.01666666666667, took 0 iterations and 0 nodes (0.00 seconds)
# Maximum depth 0, 0 variables fixed on reduced cost
# Optimal - objective value -19.016667
# Optimal - objective value -19.016667
# Cuts at root node changed objective from -19.0167 to -19.0167
# Probing was tried 0 times and created 0 cuts of which 0 were active after

# %%
if status == pywraplp.Solver.OPTIMAL:
    print('Solution:')
else:
    print('The solver did not find an optimal solution.')
# Out:
# Solution:

# %%
selected_indicators = [i for i in indicators_list if x_vars[i].solution_value() == 1]
print("\nSelected Welfare Indicators:")
for ind in selected_indicators:
    print(f"- {ind}")
# Out:
# Selected Welfare Indicators:
# - Body condition scoring
# - Calving records (death of cow)
# - Distended udder
# - Injuries
# - Physiological stress indicators

# %%
covered_hazards_animal = [h for h in hazards_animal_list if y_vars_animal[h].solution_value() == 1]
print("\nCovered Animal Hazards:")
for h in covered_hazards_animal:
    print(f"- {h}")
print(f"Total Number of Animal Hazards Covered: {len(covered_hazards_animal)}")
# Out:
# Covered Animal Hazards:
# - Continuous housing for long periods
# - Inadequate flooring in passageways, feeding and milking areas
# - Early separation of cow and calf
# - Early separation of cow and calf (after 24h)
# - Poor pasture quality
# - Poor quality feed (low nutritive value)
# - Poor quality feed (pathogens/toxins)
# - Underfeeding
# - Poor calving conditions (pen design)
# - Delayed calving intervention
# - Difficulty calving because of the sire
# - Poor calving conditions (calving management)
# - Being tied up temporarily
# - Inadequate bedding (cubicle/stall floor)
# - Inadequate design of waiting area (size, flooring, crowding gates)
# - Inadequate maintenance of milking equipment
# - Inadequate milking parlour design
# - Poor cubicle design
# - Poor stall design / stall too small
# - Use of cow trainers
# - Poor calving conditions (unable to separate from other animals)
# - Lack of handling/restraining facilities
# - Poor calving conditions (absence of pen)
# - Milking robot breakdown
# - Milking robot not used by cow
# - Mixing animals from different groups
# - Being tied without exercise for long periods
# - Fewer cubicles than cows
# - Inadequate maintenance of housing
# - Lack of space for exercise and social interactions
# - Inadequate milking equipment
# - Inadequate milking robot design
# - Insufficient protection from weather
# - Lack of facilities for sick animals
# - Too few feeding places
# - Excessive noise (constant or sudden)
# - Insufficient access to water (broken system, poor management)
# - Insufficient access to water (inappropriate system design)
# - Too few feeding places indoors
# Total Number of Animal Hazards Covered: 39

# %%
covered_hazards_consequence = [c for c in hazards_consequence_list if y_vars_consequence[c].solution_value() == 1]
print("\nCovered Consequences:")
for c in covered_hazards_consequence:
    print(f"- {c}")
print(f"Total Number of Consequences Covered: {len(covered_hazards_consequence)}")
# Out:
# Covered Consequences:
# - Separation stress
# - Prolonged hunger
# - Mortality
# - Environmental stress
# - Group (social) stress
# - Handling stress
# - Soft tissue lesions and integument damage
# - Cold stress
# - Heat stress
# - Bone lesions (incl. fractures and dislocations)
# - Inability to chew and/or ruminate
# - Isolation stress
# Total Number of Consequences Covered: 12

# %%
print(f"\nObjective Function Value: {solver.Objective().Value()}")
# Out:
# Objective Function Value: 19.016666666666666

# %%
print("\nSelected Indicators and Their Attributes:")
for ind in selected_indicators:
    attrs = indicator_attributes[ind]
    print(f"- {ind}:")
    print(f"  Indicator_Ease_Num: {attrs['Indicator_Ease_Num']}")
    print(f"  Ease_of_Hazard_Mitigation_Num: {attrs['Ease_of_Hazard_Mitigation_Num']}")
    print(f"  Indicator_Resources_Num: {attrs['Indicator_Resources_Num']}")
# Out:
# Selected Indicators and Their Attributes:
# - Body condition scoring:
#   Indicator_Ease_Num: 2.0
#   Ease_of_Hazard_Mitigation_Num: 1.5
#   Indicator_Resources_Num: 1.0
# - Calving records (death of cow):
#   Indicator_Ease_Num: 1.0
#   Ease_of_Hazard_Mitigation_Num: 1.3333333333333333
#   Indicator_Resources_Num: 1.0
# - Distended udder:
#   Indicator_Ease_Num: 1.0
#   Ease_of_Hazard_Mitigation_Num: 1.5
#   Indicator_Resources_Num: 1.0
# - Injuries:
#   Indicator_Ease_Num: 1.0
#   Ease_of_Hazard_Mitigation_Num: 2.5
#   Indicator_Resources_Num: 1.0
# - Physiological stress indicators:
#   Indicator_Ease_Num: 3.0
#   Ease_of_Hazard_Mitigation_Num: 2.15
#   Indicator_Resources_Num: 3.0
